# %% [markdown]
# CLAHE

# %%
import matplotlib.pyplot as plt

# %%
# Reading data
DATA_PATH = "data/mona_lisa.jpg"
slika = plt.imread(DATA_PATH)
plt.imshow(slika)
plt.axis('off')
# Out:
# (-0.5, 599.5, 906.5, -0.5)
